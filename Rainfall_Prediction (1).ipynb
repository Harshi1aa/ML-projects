# %% [markdown]
# ###**Rainfall prediction using linear Regression**

# %%
#importing the libraries
import numpy as np
import pandas as pd

# %%
# read the data
data = pd.read_csv("/content/austin_weather (2).csv")
data
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
# drop the unnecessary column
# Removing extra whitespaces from the column names
data.columns = data.columns.str.strip()

# Checking if the columns exist before dropping
columns_to_drop = ["Date", "SeaLevelPressureLowInches", "Events"]
columns_to_drop_existing = [col for col in columns_to_drop if col in data.columns]

# Dropping the existing columns
if columns_to_drop_existing:
    data = data.drop(columns_to_drop_existing, axis=1)
    print(f"Dropped columns: {columns_to_drop_existing}")
else:
    print("No columns found to drop.")
# Out:
# Dropped columns: ['Date', 'SeaLevelPressureLowInches', 'Events']

# %%
print(data.columns)
# Out:
# Index(['TempHighF', 'TempAvgF', 'TempLowF', 'DewPointHighF', 'DewPointAvgF',
#        'DewPointLowF', 'HumidityHighPercent', 'HumidityAvgPercent',
#        'HumidityLowPercent', 'SeaLevelPressureHighInches',
#        'SeaLevelPressureAvgInches', 'VisibilityHighMiles',
#        'VisibilityAvgMiles', 'VisibilityLowMiles', 'WindHighMPH', 'WindAvgMPH',
#        'WindGustMPH', 'PrecipitationSumInches'],
#       dtype='object')

# %%
data = data.replace('T',0.0)

# %%
data = data.replace('-',0.0)

# %%
data.to_csv("austin_weather_final.csv")

# %%
# importing libraries
import numpy as np
import pandas as pd
import sklearn as sk
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("austin_weather_final.csv")
data
# Out:
#       Unnamed: 0  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0              0         74        60        45           67.0          49.0
# 1              1         56        48        39           43.0          36.0
# 2              2         58        45        32           31.0          27.0
# 3              3         61        46        31           36.0          28.0
# 4              4         58        50        41           44.0          40.0
# ...          ...        ...       ...       ...            ...           ...
# 1314        1314        103        89        75           71.0          67.0
# 1315        1315        105        91        76           71.0          64.0
# 1316        1316        107        92        77           72.0          64.0
# 1317        1317        106        93        79           70.0          68.0
# 1318        1318         99        88        77           66.0          61.0
#
# ...

# %%
X = data.drop(["PrecipitationSumInches"],axis = 1)
Y = data["PrecipitationSumInches"]

# %%
X = data.drop(["PrecipitationSumInches"], axis=1)
# reshaping it into 2D vector
Y = data["PrecipitationSumInches"].values.reshape(-1, 1)
Yday_index = 798
days = [i for i in range(Y.size)]

# %%
# initialise the linear regression classifier
clf = LinearRegression()

#train the classifier
clf.fit(X,Y)
# Out:
# LinearRegression()

# %%
#plot a graph
print("The Percipitation trend graph:")
plt.scatter(days, Y, color = 'g')
plt.scatter(days[day_index], Y[day_index], color='r')
plt.title("Percipitation level")
plt.xlabel("Days")
plt.ylabel("Percipitation in inches")
plt.show()
x_vis = X.filter(['TempAvgF','DewPointAvgF','HumidityAvgPercent','SeaLevelPressureAvgInches','VisibilityAvgMiles','WindAvgMPH'])
# Out:
# The Percipitation trend graph:

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression


# Plot a graph
print("The Precipitation trend graph:")
x_vis = X.filter(['TempAvgF', 'DewPointAvgF', 'HumidityAvgPercent', 'SeaLevelPressureAvgInches', 'VisibilityAvgMiles', 'WindAvgMPH'])

for i, col in enumerate(x_vis.columns):
    plt.subplot(3, 2, i + 1)
    plt.scatter(days, x_vis[col][:len(days)], color='g')
    plt.scatter(days[Yday_index], x_vis[col][Yday_index], color='r')
    plt.title(col)

plt.show()
# Out:
# The Precipitation trend graph:
